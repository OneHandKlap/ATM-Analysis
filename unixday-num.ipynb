# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as seabornInstance
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from datetime import datetime


dataset = pd.read_csv("C:/Users/pabou/Documents/GitHub/Web-Scraper/data/Cleaned/Cleaned_Depanneur Amigos Gatineau.csv")
print(dataset.describe())
dataset["Date"]=pd.to_datetime(dataset["Date"])
dataset["Time"]=pd.to_datetime(dataset["Time"])
dataset["Date-Time"]=pd.to_datetime(dataset["Date-Time"])
dataset["Unix day"]=dataset["Date"].astype(np.int64)//10**9
print(dataset.head())
# Out:
# Unnamed: 0
# count  4445.000000
# mean   2836.579528
# std    1629.291245
# min       0.000000
# 25%    1429.000000
# 50%    2836.000000
# 75%    4242.000000
# max    5659.000000
#    Unnamed: 0       Date                Time        Type           Date-Time  \
# 0           0 2017-12-11 2019-12-14 13:31:33  Withdrawal 2017-12-11 13:31:33
# 1           2 2017-12-11 2019-12-14 21:59:36  Withdrawal 2017-12-11 21:59:36
# 2           3 2017-12-12 2019-12-14 12:34:09  Withdrawal 2017-12-12 12:34:09
# 3           4 2017-12-12 2019-12-14 16:38:24  Withdrawal 2017-12-12 16:38:24
# 4           5 2017-12-12 2019-12-14 16:54:26  Withdrawal 2017-12-12 16:54:26
#
#           Fee      Amount    Status    Unix day
# 0  $     2.50  $   120.00  Approved  1512950400
# 1  $     2.50  $   100.00  Approved  1512950400
# 2  $     2.50  $    20.00  Approved  1513036800
# 3  $     2.50  $    80.00  Approved  1513036800
# 4  $     2.50  $    40.00  Approved  1513036800

# %%
newDataset=pd.DataFrame

dataset["keys"]=dataset["Unix day"].value_counts().keys().tolist()
dataset["vals"]=dataset["Unix day"].value_counts().tolist()
plt.plot(keys,vals,'o')
plt.title('Date vs Number of Transactions')
plt.xlabel('Unix Day')
plt.ylabel('Number of Transactions')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-69cfed3c054a> in <module>
#       3 keys=dataset["Unix day"].value_counts().keys().tolist()
#       4 vals=dataset["Unix day"].value_counts().tolist()
# ----> 5 newDataset["keys"]=np.array(keys)
#       6 newDataset["vals"]=np.array(vals)
#       7 plt.plot(keys,vals,'o')
#
# TypeError: 'type' object does not support item assignment

# %%
plt.figure(figsize=(15,10))
plt.tight_layout()
seabornInstance.distplot(dataset['Unix day'])

# %%
X=keys #individual days over a two year period will be our attribute set
Y=vals #number of transactions will be our label set (ie. what we want to predict)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
