# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as seabornInstance
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from datetime import datetime


dataset = pd.read_csv("C:/Users/pabou/Documents/GitHub/Web-Scraper/data/Cleaned_Depanneur_Amigos_Gatineau.csv")
dataset["Time"].to_timestamp()
dataset.describe(how="start",copy=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-73b6aab9f0de> in <module>
#       9
#      10 dataset = pd.read_csv("C:/Users/pabou/Documents/GitHub/Web-Scraper/data/Cleaned_Depanneur_Amigos_Gatineau.csv")
# ---> 11 dataset["Time"].to_timestamp()
#      12 dataset.describe()
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\series.py in to_timestamp(self, freq, how, copy)
#    4840             new_values = new_values.copy()
#    4841
# -> 4842         new_index = self.index.to_timestamp(freq=freq, how=how)
#    4843         return self._constructor(new_values, index=new_index).__finalize__(self)
#    4844
#
# AttributeError: 'RangeIndex' object has no attribute 'to_timestamp'

# %%
dataset.plot(x="Fee",y="Amount",style='o')
plt.title('Time vs Fee')
plt.xlabel('Time')
plt.ylabel('Amount')
# Out:
# Text(0, 0.5, 'Amount')

# %%
plt.figure(figsize=(15,10))
plt.tight_layout()
seabornInstance.distplot(dataset["Fee"])
