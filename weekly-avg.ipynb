# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as seabornInstance
import numpy
os.chdir("C:/Users\pabou\Documents\GitHub\Web-Scraper\data\Cleaned\cleaned2")
dataset=pd.read_csv("Cleaned2_Cleaned_Depanneur Amigos Gatineau.csv")

keys=dataset["Week"].value_counts().keys().tolist()
vals=dataset["Week"].value_counts().tolist()
plt.plot(keys,vals,'o')
plt.xlabel("Weeks")
plt.ylabel("Number of Transactions")
z = numpy.polyfit(keys, vals, 1)
p = numpy.poly1d(z)
plt.plot(keys,p(keys),"r--")
# Out:
# 14    135
# 22    125
# 35    124
# 44    111
# 9     109
# 31    108
# 27    108
# 18    108
# 39    103
# 26    103
# 25    100
# 47    100
# 40     99
# 50     98
# 48     93
# 51     92
# 8      92
# 6      90
# 16     89
# 13     88
# 29     88
# 12     85
# 19     84
# 20     84
# 7      84
# 10     83
# 37     82
# 33     82
# 43     81
# 24     81
# 23     80
# 41     76
# 21     76
# 34     76
# 5      75
# 49     75
# 15     75
# 38     74
# 36     74
# 3      72
# 45     70
# 2      70
# 46     69
# 11     69
# 17     68
# 32     67
# 42     67
# 52     66
# 4      63
# 28     60
# 30     58
# 1      56
# Name: Week, dtype: int64

# %%
d={}
for i in dataset['Week'].unique():
    d[i] = [dataset['Amount'][j].tolist() for j in dataset[dataset['Week']==i].index]
print(d)
# Out:
# .0}, {31: 100.0}, {31: 140.0}, {31: 60.0}, {31: 100.0}, {31: 80.0}, {31: 100.0}, {31: 20.0}, {31: 100.0}, {31: 100.0}, {31: 100.0}, {31: 100.0}, {31: 400.0}, {31: 100.0}, {31: 20.0}, {31: 100.0}, {31: 100.0}, {31: 60.0}, {31: 100.0}, {31: 80.0}, {31: 100.0}, {31: 120.0}, {31: 100.0}, {31: 100.0}, {31: 100.0}, {31: 120.0}, {31: 400.0}, {31: 300.0}, {31: 400.0}, {31: 20.0}, {31: 400.0}, {31: 40.0}, {31: 100.0}, {31: 400.0}, {31: 400.0}, {31: 100.0}, {31: 100.0}, {31: 100.0}, {31: 100.0}, {31: 100.0}, {31: 400.0}, {31: 40.0}, {31: 60.0}, {31: 300.0}, {31: 60.0}, {31: 160.0}, {31: 20.0}, {31: 40.0}, {31: 400.0}, {31: 100.0}, {31: 160.0}, {31: 60.0}, {31: 120.0}, {31: 100.0}, {31: 80.0}, {31: 400.0}, {31: 100.0}, {31: 160.0}, {31: 300.0}, {31: 100.0}, {31: 20.0}, {31: 100.0}, {31: 20.0}, {31: 260.0}, {31: 40.0}, {31: 300.0}, {31: 20.0}, {31: 100.0}], 32: [{32: 40.0}, {32: 20.0}, {32: 100.0}, {32: 200.0}, {32: 60.0}, {32: 100.0}, {32: 60.0}, {32: 100.0}, {32: 40.0}, {32: 120.0}, {32: 20.0}, {32: 400.0}, {32: 60.0}, {32: 40.0}, {32: 60.0}, {32: 20.0}, {32: 100.0}, {32: 200.0}, {32: 160.0}, {32: 160.0}, {32: 40.0}, {32: 260.0}, {32: 400.0}, {32: 300.0}, {32: 60.0}, {32: 40.0}, {32: 20.0}, {32: 60.0}, {32: 100.0}, {32: 300.0}, {32: 100.0}, {32: 100.0}, {32: 60.0}, {32: 100.0}, {32: 100.0}, {32: 220.0}, {32: 200.0}, {32: 80.0}, {32: 20.0}, {32: 60.0}, {32: 100.0}, {32: 140.0}, {32: 400.0}, {32: 100.0}, {32: 60.0}, {32: 40.0}, {32: 40.0}, {32: 40.0}, {32: 200.0}, {32: 20.0}, {32: 60.0}, {32: 60.0}, {32: 240.0}, {32: 400.0}, {32: 400.0}, {32: 80.0}, {32: 80.0}, {32: 80.0}, {32: 20.0}, {32: 40.0}, {32: 60.0}, {32: 100.0}, {32: 40.0}, {32: 100.0}, {32: 40.0}, {32: 40.0}, {32: 80.0}], 33: [{33: 120.0}, {33: 40.0}, {33: 40.0}, {33: 60.0}, {33: 140.0}, {33: 180.0}, {33: 60.0}, {33: 80.0}, {33: 40.0}, {33: 300.0}, {33: 80.0}, {33: 100.0}, {33: 200.0}, {33: 80.0}, {33: 40.0}, {33: 40.0}, {33: 220.0}, {33: 200.0}, {33: 40.0}, {33: 60.0}, {33: 400.0}, {33: 100.0}, {33: 300.0}, {33: 180.0}, {33: 100.0}, {33: 160.0}, {33: 40.0}, {33: 20.0}, {33: 100.0}, {33: 100.0}, {33: 60.0}, {33: 160.0}, {33: 20.0}, {33: 100.0}, {33: 200.0}, {33: 80.0}, {33: 60.0}, {33: 40.0}, {33: 20.0}, {33: 20.0}, {33: 200.0}, {33: 100.0}, {33: 40.0}, {33: 60.0}, {33: 100.0}, {33: 300.0}, {33: 400.0}, {33: 60.0}, {33: 20.0}, {33: 400.0}, {33: 60.0}, {33: 40.0}, {33: 60.0}, {33: 40.0}, {33: 240.0}, {33: 60.0}, {33: 20.0}, {33: 100.0}, {33: 400.0}, {33: 20.0}, {33: 60.0}, {33: 40.0}, {33: 20.0}, {33: 180.0}, {33: 80.0}, {33: 160.0}, {33: 100.0}, {33: 80.0}, {33: 100.0}, {33: 100.0}, {33: 80.0}, {33: 200.0}, {33: 100.0}, {33: 100.0}, {33: 140.0}, {33: 60.0}, {33: 20.0}, {33: 400.0}, {33: 40.0}, {33: 40.0}, {33: 100.0}, {33: 300.0}], 34: [{34: 100.0}, {34: 60.0}, {34: 340.0}, {34: 400.0}, {34: 100.0}, {34: 100.0}, {34: 80.0}, {34: 40.0}, {34: 60.0}, {34: 100.0}, {34: 20.0}, {34: 20.0}, {34: 40.0}, {34: 280.0}, {34: 400.0}, {34: 20.0}, {34: 300.0}, {34: 20.0}, {34: 300.0}, {34: 40.0}, {34: 60.0}, {34: 100.0}, {34: 40.0}, {34: 40.0}, {34: 60.0}, {34: 80.0}, {34: 120.0}, {34: 80.0}, {34: 80.0}, {34: 100.0}, {34: 20.0}, {34: 400.0}, {34: 60.0}, {34: 140.0}, {34: 40.0}, {34: 100.0}, {34: 60.0}, {34: 40.0}, {34: 20.0}, {34: 160.0}, {34: 80.0}, {34: 20.0}, {34: 320.0}, {34: 120.0}, {34: 20.0}, {34: 60.0}, {34: 80.0}, {34: 100.0}, {34: 80.0}, {34: 40.0}, {34: 40.0}, {34: 400.0}, {34: 40.0}, {34: 140.0}, {34: 200.0}, {34: 100.0}, {34: 60.0}, {34: 200.0}, {34: 40.0}, {34: 100.0}, {34: 40.0}, {34: 20.0}, {34: 400.0}, {34: 80.0}, {34: 40.0}, {34: 240.0}, {34: 60.0}, {34: 40.0}, {34: 100.0}, {34: 100.0}, {34: 100.0}, {34: 200.0}, {34: 100.0}, {34: 20.0}, {34: 100.0}, {34: 60.0}], 35: [{35: 40.0}, {35: 100.0}, {35: 200.0}, {35: 20.0}, {35: 20.0}, {35: 20.0}, {35: 20.0}, {35: 40.0}, {35: 60.0}, {35: 240.0}, {35: 20.0}, {35: 100.0}, {35: 300.0}, {35: 100.0}, {35: 60.0}, {35: 20.0}, {35: 20.0}, {35: 40.0}, {35: 140.0}, {35: 40.0}, {35: 20.0}, {35: 100.0}, {35: 120.0}, {35: 200.0}, {35: 400.0}, {35 ...

# %%
print (week_amount_dict)
# Out:
# {50: 20.0, 51: 80.0, 52: 60.0, 1: 100.0, 2: 20.0, 3: 80.0, 4: 40.0, 5: 80.0, 6: 20.0, 7: 200.0, 8: 400.0, 9: 260.0, 10: 200.0, 11: 140.0, 12: 400.0, 13: 40.0, 14: 40.0, 15: 80.0, 16: 100.0, 17: 80.0, 18: 100.0, 19: 40.0, 20: 40.0, 21: 80.0, 22: 120.0, 23: 80.0, 24: 20.0, 25: 200.0, 26: 100.0, 27: 40.0, 28: 100.0, 29: 40.0, 30: 80.0, 31: 40.0, 32: 200.0, 33: 300.0, 34: 160.0, 35: 200.0, 36: 100.0, 37: 120.0, 38: 300.0, 39: 40.0, 40: 300.0, 41: 160.0, 42: 60.0, 43: 80.0, 44: 300.0, 45: 140.0, 46: 120.0, 47: 100.0, 48: 200.0, 49: 80.0}
